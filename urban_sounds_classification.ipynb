# %%
# Basic Libraries

import pandas as pd
import numpy as np

pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import MinMaxScaler

# %%
# Libraries for Classification and building Models

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, Dropout
from tensorflow.keras.utils import to_categorical 

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# Project Specific Libraries

import os
import librosa
import librosa.display
import glob 
import skimage

# %%
df = pd.read_csv("./UrbanSound8K.csv")

'''We will extract classes from this metadata.'''

df.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
dat1, sampling_rate1 = librosa.load('./audio/fold5/100032-3-0-0.wav')
dat2, sampling_rate2 = librosa.load('./audio/fold5/100263-2-0-117.wav')

# %%
plt.figure(figsize=(20, 10))
D = librosa.amplitude_to_db(np.abs(librosa.stft(dat1)), ref=np.max)
plt.subplot(4, 2, 1)
librosa.display.specshow(D, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Linear-frequency power spectrogram')

# %%
plt.figure(figsize=(20, 10))
D = librosa.amplitude_to_db(np.abs(librosa.stft(dat2)), ref=np.max)
plt.subplot(4, 2, 1)
librosa.display.specshow(D, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Linear-frequency power spectrogram')

# %%
'''Using random samples to observe difference in waveforms.'''

arr = np.array(df["slice_file_name"])
fold = np.array(df["fold"])
cla = np.array(df["class"])

for i in range(192, 197, 2):
    path = './audio/fold' + str(fold[i]) + '/' + arr[i]
    data, sampling_rate = librosa.load(path)
    plt.figure(figsize=(10, 5))
    D = librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max)
    plt.subplot(4, 2, 1)
    librosa.display.specshow(D, y_axis='linear')
    plt.colorbar(format='%+2.0f dB')
    plt.title(cla[i])

# %%
'''EXAMPLE'''

dat1, sampling_rate1 = librosa.load('./audio/fold5/100032-3-0-0.wav')
arr = librosa.feature.melspectrogram(y=dat1, sr=sampling_rate1)
arr.shape
# Out:
# (128, 14)

# %%
feature = []
label = []

def parser(row):
    # Function to load files and extract features
    for i in range(8732):
        file_name = './audio/fold' + str(df["fold"][i]) + '/' + df["slice_file_name"][i]
        # Here kaiser_fast is a technique used for faster extraction
        X, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        # We extract mfcc feature from data
        mels = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate).T,axis=0)        
        feature.append(mels)
        label.append(df["classID"][i])
    return [feature, label]

# %%
temp = parser(df)
# Out:
# c:\Python310\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# c:\Python310\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1103
#   return f(*args, **kwargs)
# c:\Python310\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1523
#   return f(*args, **kwargs)

# %%
temp = np.array(temp)
data = temp.transpose()
# Out:
# C:\Users\oo\AppData\Local\Temp\ipykernel_25092\1993562939.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   temp = np.array(temp)

# %%
X_ = data[:, 0]
Y = data[:, 1]
print(X_.shape, Y.shape)
X = np.empty([8732, 128])
# Out:
# (8732,) (8732,)

# %%
for i in range(8732):
    X[i] = (X_[i])

# %%
Y = to_categorical(Y)

# %%
'''Final Data'''
print(X.shape)
print(Y.shape)
# Out:
# (8732, 128)
# (8732, 10)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 1)

# %%
X_train = X_train.reshape(6549, 16, 8, 1)
X_test = X_test.reshape(2183, 16, 8, 1)

# %%
input_dim = (16, 8, 1)

# %%
model = Sequential()

# %%
model.add(Conv2D(64, (3, 3), padding = "same", activation = "tanh", input_shape = input_dim))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), padding = "same", activation = "tanh"))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(1024, activation = "tanh"))
model.add(Dense(10, activation = "softmax"))

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train, epochs = 90, batch_size = 50, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/90
# 131/131 [==============================] - 5s 32ms/step - loss: 1.5445 - accuracy: 0.4724 - val_loss: 1.4285 - val_accuracy: 0.5066
# Epoch 2/90
# 131/131 [==============================] - 4s 32ms/step - loss: 1.1511 - accuracy: 0.6141 - val_loss: 1.1120 - val_accuracy: 0.6477
# Epoch 3/90
# 131/131 [==============================] - 4s 34ms/step - loss: 0.9554 - accuracy: 0.6764 - val_loss: 1.0308 - val_accuracy: 0.6679
# Epoch 4/90
# 131/131 [==============================] - 4s 33ms/step - loss: 0.8431 - accuracy: 0.7171 - val_loss: 0.9479 - val_accuracy: 0.6890
# Epoch 5/90
# 131/131 [==============================] - 4s 34ms/step - loss: 0.7603 - accuracy: 0.7488 - val_loss: 0.9801 - val_accuracy: 0.7045
# Epoch 6/90
# 131/131 [==============================] - 5s 36ms/step - loss: 0.7034 - accuracy: 0.7678 - val_loss: 0.9050 - val_accuracy: 0.7261
# Epoch 7/90
# 131/131 [==============================] - 5s 40ms/step - loss: 0.6175 - accuracy: 0.7984 - val_loss: 0.9273 - val_accuracy: 0.7339
# Epoch 8/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.5873 - accuracy: 0.8090 - val_loss: 0.8102 - val_accuracy: 0.7586
# Epoch 9/90
# 131/131 [==============================] - 5s 36ms/step - loss: 0.5507 - accuracy: 0.8221 - val_loss: 0.8688 - val_accuracy: 0.7554
# Epoch 10/90
# 131/131 [==============================] - 4s 32ms/step - loss: 0.4833 - accuracy: 0.8377 - val_loss: 0.8400 - val_accuracy: 0.7705
# Epoch 11/90
# 131/131 [==============================] - 4s 28ms/step - loss: 0.4575 - accuracy: 0.8476 - val_loss: 0.8422 - val_accuracy: 0.7627
# Epoch 12/90
# 131/131 [==============================] - 4s 31ms/step - loss: 0.4458 - accuracy: 0.8545 - val_loss: 0.8340 - val_accuracy: 0.7714
# Epoch 13/90
# 131/131 [==============================] - 4s 29ms/step - loss: 0.4252 - accuracy: 0.8623 - val_loss: 0.7727 - val_accuracy: 0.7884
# Epoch 14/90
# 131/131 [==============================] - 4s 29ms/step - loss: 0.4273 - accuracy: 0.8615 - val_loss: 0.9486 - val_accuracy: 0.7627
# Epoch 77/90
# 131/131 [==============================] - 5s 36ms/step - loss: 0.0733 - accuracy: 0.9745 - val_loss: 0.9196 - val_accuracy: 0.8530
# Epoch 78/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.0679 - accuracy: 0.9756 - val_loss: 0.9088 - val_accuracy: 0.8511
# Epoch 79/90
# 131/131 [==============================] - 5s 36ms/step - loss: 0.0755 - accuracy: 0.9739 - val_loss: 0.8912 - val_accuracy: 0.8475
# Epoch 80/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.0705 - accuracy: 0.9747 - val_loss: 0.8660 - val_accuracy: 0.8662
# Epoch 81/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.0828 - accuracy: 0.9736 - val_loss: 0.8251 - val_accuracy: 0.8621
# Epoch 82/90
# 131/131 [==============================] - 4s 34ms/step - loss: 0.0686 - accuracy: 0.9765 - val_loss: 0.8302 - val_accuracy: 0.8630
# Epoch 83/90
# 131/131 [==============================] - 5s 36ms/step - loss: 0.0690 - accuracy: 0.9791 - val_loss: 0.8823 - val_accuracy: 0.8621
# Epoch 84/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.0608 - accuracy: 0.9798 - val_loss: 0.8554 - val_accuracy: 0.8571
# Epoch 85/90
# 131/131 [==============================] - 5s 34ms/step - loss: 0.0502 - accuracy: 0.9823 - val_loss: 0.8597 - val_accuracy: 0.8658
# Epoch 86/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.0483 - accuracy: 0.9831 - val_loss: 0.8196 - val_accuracy: 0.8672
# Epoch 87/90
# 131/131 [==============================] - 5s 36ms/step - loss: 0.0526 - accuracy: 0.9814 - val_loss: 0.8248 - val_accuracy: 0.8685
# Epoch 88/90
# 131/131 [==============================] - 5s 36ms/step - loss: 0.0470 - accuracy: 0.9838 - val_loss: 0.9152 - val_accuracy: 0.8644
# Epoch 89/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.0614 - accuracy: 0.9789 - val_loss: 0.8455 - val_accuracy: 0.8672
# Epoch 90/90
# 131/131 [==============================] - 5s 35ms/step - loss: 0.0573 - accuracy: 0.9820 - val_loss: 0.9513 - val_accuracy: 0.8598

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 8, 64)         640
#
#  max_pooling2d (MaxPooling2D  (None, 8, 4, 64)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 4, 128)         73856
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 2, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 4, 2, 128)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 1,134,346
# Trainable params: 1,134,346
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print(score)
# Out:
# 69/69 [==============================] - 1s 8ms/step
# 69/69 [==============================] - 1s 7ms/step - loss: 0.9513 - accuracy: 0.8598
# [0.9513192772865295, 0.8598259091377258]

# %%
preds = np.argmax(predictions, axis = 1)

# %%
result = pd.DataFrame(preds)
result.to_csv("UrbanSound8kResults.csv")
